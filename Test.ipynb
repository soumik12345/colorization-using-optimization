# %%
from colorization import Colorizer
from matplotlib import pyplot as plt

# %%
colorizer = Colorizer(
    gray_image_file='./data/example.bmp',
    visual_clues_file='./data/example_marked.bmp'
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_36259/573016460.py in <module>
# ----> 1 colorizer = Colorizer(
#       2     original_image='./data/example.bmp',
#       3     visual_clues='./data/example_marked.bmp'
#       4 )
#
# TypeError: __init__() got an unexpected keyword argument 'original_image'

# %%
colorizer.plot_inputs()

# %%
result = colorizer.colorize()

# %%
colorizer.plot_results(result)
